# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\KIIT\Documents\Downloads\gender_classifier.csv",encoding=('ISO-8859-1'))

# %%
df2=pd.read_csv(r"C:\Users\KIIT\Documents\Downloads\gender_classifier.csv",encoding=('ISO-8859-1'))
df3=pd.read_csv(r"C:\Users\KIIT\Documents\Downloads\gender_classifier.csv",encoding=('ISO-8859-1'))

# %%
df.head(10)
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
# 5  815719231    False   finalized                   3     10/27/15 1:47
# 6  815719232    False   finalized                   3     10/27/15 1:57
# 7  815719233    False   finalized                   3    10/26/15 23:48
# 8  815719234    False   finalized                   3     10/27/15 1:52
# 9  815719235    False   finalized                   3     10/27/15 1:49
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# ...

# %%
df.groupby(['gender']).count()
# Out:
#          _unit_id  _golden  _unit_state  _trusted_judgments  \
# gender
# brand        5942     5942         5942                5942
# female       6700     6700         6700                6700
# male         6194     6194         6194                6194
# unknown      1117     1117         1117                1117
#
#          _last_judgment_at  gender:confidence  profile_yn  \
# gender
# brand                 5928               5942        5942
# female                6685               6700        6700
# male                  6173               6194        6194
# unknown               1117               1117        1117
#
#          profile_yn:confidence  created  description  ...  profileimage  \
# gender                                                ...
# brand                     5942     5942         4328  ...          5942
# female                    6700     6700         5725  ...          6700
# male                      6194     6194         5469  ...          6194
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16306 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  gender_gold            50 non-null     object
#  13  link_color             20050 non-null  object
# ...

# %%
df.drop('gender_gold',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
# 5  815719231    False   finalized                   3     10/27/15 1:47
# 6  815719232    False   finalized                   3     10/27/15 1:57
# 7  815719233    False   finalized                   3    10/26/15 23:48
# 8  815719234    False   finalized                   3     10/27/15 1:52
# 9  815719235    False   finalized                   3     10/27/15 1:49
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16306 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  link_color             20050 non-null  object
#  13  name                   20050 non-null  object
# ...

# %%
df['description'].head(10)
# Out:
# 0                                i sing my own rhythm.
# 1    I'm the author of novels filled with family dr...
# 2                  louis whining and squealing and all
# 3    Mobile guy.  49ers, Shazam, Google, Kleiner Pe...
# 4    Ricky Wilson The Best FRONTMAN/Kaiser Chiefs T...
# 5                                   you don't know me.
# 6    A global marketplace for images, videos and mu...
# 7      The secret of getting ahead is getting started.
# 8           Pll Fan // Crazy about MCD // Ramen is bae
# 9    Renaissance art historian, University of Notti...
# Name: description, dtype: object

# %%
df['tweet_coord'].head(10)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: tweet_coord, dtype: object

# %%
df['tweet_coord'].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 20045    True
# 20046    True
# 20047    True
# 20048    True
# 20049    True
# Name: tweet_coord, Length: 20050, dtype: bool

# %%
df.drop('tweet_coord',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
# 5  815719231    False   finalized                   3     10/27/15 1:47
# 6  815719232    False   finalized                   3     10/27/15 1:57
# 7  815719233    False   finalized                   3    10/26/15 23:48
# 8  815719234    False   finalized                   3     10/27/15 1:52
# 9  815719235    False   finalized                   3     10/27/15 1:49
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# ...

# %%
df.corr()['gender']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bb3c9d636354> in <module>
# ...

# %%
df[df['gender']=='male'].index
# Out:
# Int64Index([    0,     1,     2,     3,     7,    17,    18,    23,    24,
#                29,
#             ...
#             20023, 20026, 20027, 20031, 20032, 20037, 20040, 20043, 20046,
#             20047],
#            dtype='int64', length=6194)

# %%
df.drop(df[df['gender']!='male' or df['gender']!='female'].index,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d5380803d99a> in <module>
# ----> 1 df.drop(df[df['gender']!='male' or df['gender']!='female'].index,inplace=False)
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.drop(df[df['gender']=='brand'].index,inplace=True)

# %%
df.head(10)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0   815719226    False   finalized                   3    10/26/15 23:24
# 1   815719227    False   finalized                   3    10/26/15 23:30
# 2   815719228    False   finalized                   3    10/26/15 23:33
# 3   815719229    False   finalized                   3    10/26/15 23:10
# 4   815719230    False   finalized                   3     10/27/15 1:15
# 5   815719231    False   finalized                   3     10/27/15 1:47
# 7   815719233    False   finalized                   3    10/26/15 23:48
# 8   815719234    False   finalized                   3     10/27/15 1:52
# 9   815719235    False   finalized                   3     10/27/15 1:49
# 12  815719238    False   finalized                   3    10/26/15 22:20
#
#     gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0     male             1.0000        yes                    1.0
# ...

# %%
df['gender'].values
# Out:
# array(['male', 'male', 'male', ..., 'male', 'female', 'female'],
#       dtype=object)

# %%
df['gender'].shape[0]
# Out:
# 14108

# %%
if df['gender'].values[0] == 'male':
    print('true')
# Out:
# true

# %%
df[df['gender']!='brand'].head(10)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0   815719226    False   finalized                   3    10/26/15 23:24
# 1   815719227    False   finalized                   3    10/26/15 23:30
# 2   815719228    False   finalized                   3    10/26/15 23:33
# 3   815719229    False   finalized                   3    10/26/15 23:10
# 4   815719230    False   finalized                   3     10/27/15 1:15
# 5   815719231    False   finalized                   3     10/27/15 1:47
# 7   815719233    False   finalized                   3    10/26/15 23:48
# 8   815719234    False   finalized                   3     10/27/15 1:52
# 9   815719235    False   finalized                   3     10/27/15 1:49
# 12  815719238    False   finalized                   3    10/26/15 22:20
#
#     gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0     male             1.0000        yes                    1.0
# ...

# %%
df.drop(df[df['gender']=='unknown'].index,inplace=True)

# %%
df.head(30)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0   815719226    False   finalized                   3    10/26/15 23:24
# 1   815719227    False   finalized                   3    10/26/15 23:30
# 2   815719228    False   finalized                   3    10/26/15 23:33
# 3   815719229    False   finalized                   3    10/26/15 23:10
# 4   815719230    False   finalized                   3     10/27/15 1:15
# 5   815719231    False   finalized                   3     10/27/15 1:47
# 7   815719233    False   finalized                   3    10/26/15 23:48
# 8   815719234    False   finalized                   3     10/27/15 1:52
# 9   815719235    False   finalized                   3     10/27/15 1:49
# 12  815719238    False   finalized                   3    10/26/15 22:20
# 14  815719240    False   finalized                   3     10/27/15 1:29
# 15  815719241    False   finalized                   3     10/27/15 1:50
# ...

# %%
df.shape
# Out:
# (12991, 24)

# %%
df.groupby(['gender']).count()
# Out:
#         _unit_id  _golden  _unit_state  _trusted_judgments  _last_judgment_at  \
# gender
# female      6700     6700         6700                6700               6685
# male        6194     6194         6194                6194               6173
#
#         gender:confidence  profile_yn  profile_yn:confidence  created  \
# gender
# female               6700        6700                   6700     6700
# male                 6194        6194                   6194     6194
#
#         description  ...  profile_yn_gold  profileimage  retweet_count  \
# gender               ...
# female         5725  ...               15          6700           6700
# male           5469  ...               21          6194           6194
#
#         sidebar_color  text  tweet_count  tweet_created  tweet_id  \
# gender
# female           6700  6700         6700           6700      6700
# male             6194  6194         6194           6194      6194
#
#         tweet_location  user_timezone
# ...

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ... profile_yn_gold  \
# 0    12/5/13 1:48  ...             NaN
# 1   10/1/12 13:51  ...             NaN
# ...

# %%
df['_unit_state'].unique()
# Out:
# array(['finalized', 'golden'], dtype=object)

# %%
df.groupby(['_unit_state']).count()
# Out:
#              _unit_id  _golden  _trusted_judgments  _last_judgment_at  gender  \
# _unit_state
# finalized       12955    12955               12955              12955   12858
# golden             36       36                  36                  0      36
#
#              gender:confidence  profile_yn  profile_yn:confidence  created  \
# _unit_state
# finalized                12929       12955                  12955    12955
# golden                      36          36                     36       36
#
#              description  ...  profile_yn_gold  profileimage  retweet_count  \
# _unit_state               ...
# finalized          11244  ...                0         12955          12955
# golden                32  ...               36            36             36
#
#              sidebar_color   text  tweet_count  tweet_created  tweet_id  \
# _unit_state
# finalized            12955  12955        12955          12955     12955
# ...

# %%
df.drop(['profileimage'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0   815719226    False   finalized                   3    10/26/15 23:24
# 1   815719227    False   finalized                   3    10/26/15 23:30
# 2   815719228    False   finalized                   3    10/26/15 23:33
# 3   815719229    False   finalized                   3    10/26/15 23:10
# 4   815719230    False   finalized                   3     10/27/15 1:15
# 5   815719231    False   finalized                   3     10/27/15 1:47
# 7   815719233    False   finalized                   3    10/26/15 23:48
# 8   815719234    False   finalized                   3     10/27/15 1:52
# 9   815719235    False   finalized                   3     10/27/15 1:49
# 12  815719238    False   finalized                   3    10/26/15 22:20
#
#     gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0     male             1.0000        yes                    1.0
# ...

# %%
df.groupby(['retweet_count']).count()
# Out:
#                _unit_id  _golden  _unit_state  _trusted_judgments  \
# retweet_count
# 0                 12592    12592        12592               12592
# 1                   328      328          328                 328
# 2                    35       35           35                  35
# 3                     8        8            8                   8
# 4                     2        2            2                   2
# 5                     3        3            3                   3
# 6                     8        8            8                   8
# 7                     2        2            2                   2
# 8                     2        2            2                   2
# 9                     1        1            1                   1
# 10                    1        1            1                   1
# 11                    3        3            3                   3
# 20                    2        2            2                   2
# ...

# %%
df.dtypes
# Out:
# _unit_id                   int64
# _golden                     bool
# _unit_state               object
# _trusted_judgments         int64
# _last_judgment_at         object
# gender                    object
# gender:confidence        float64
# profile_yn                object
# profile_yn:confidence    float64
# created                   object
# description               object
# fav_number                 int64
# link_color                object
# name                      object
# profile_yn_gold           object
# retweet_count              int64
# sidebar_color             object
# text                      object
# tweet_count                int64
# tweet_created             object
# tweet_id                 float64
# tweet_location            object
# user_timezone             object
# dtype: object

# %%
df.drop(['tweet_created'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (12991, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12991 non-null  int64
#  1   _golden                12991 non-null  bool
#  2   _unit_state            12991 non-null  object
#  3   _trusted_judgments     12991 non-null  int64
#  4   _last_judgment_at      12955 non-null  object
#  5   gender                 12894 non-null  object
#  6   gender:confidence      12965 non-null  float64
#  7   profile_yn             12991 non-null  object
#  8   profile_yn:confidence  12991 non-null  float64
#  9   created                12991 non-null  object
#  10  description            11276 non-null  object
#  11  fav_number             12991 non-null  int64
#  12  link_color             12991 non-null  object
#  13  name                   12991 non-null  object
# ...

# %%
df['profile_yn_gold'].unique()
# Out:
# array([nan, 'yes'], dtype=object)

# %%
df.drop(['profile_yn_gold'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (12991, 21)

# %%
df.drop(['_last_judgment_at'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (12991, 20)

# %%
df.drop(['description'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (12991, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12991 non-null  int64
#  1   _golden                12991 non-null  bool
#  2   _unit_state            12991 non-null  object
#  3   _trusted_judgments     12991 non-null  int64
#  4   gender                 12894 non-null  object
#  5   gender:confidence      12965 non-null  float64
#  6   profile_yn             12991 non-null  object
#  7   profile_yn:confidence  12991 non-null  float64
#  8   created                12991 non-null  object
#  9   fav_number             12991 non-null  int64
#  10  link_color             12991 non-null  object
#  11  name                   12991 non-null  object
#  12  retweet_count          12991 non-null  int64
#  13  sidebar_color          12991 non-null  object
# ...

# %%
df.groupby(['gender']).count()
# Out:
#         _unit_id  _golden  _unit_state  _trusted_judgments  gender:confidence  \
# gender
# female      6700     6700         6700                6700               6700
# male        6194     6194         6194                6194               6194
#
#         profile_yn  profile_yn:confidence  created  fav_number  link_color  \
# gender
# female        6700                   6700     6700        6700        6700
# male          6194                   6194     6194        6194        6194
#
#         name  retweet_count  sidebar_color  text  tweet_count  tweet_id  \
# gender
# female  6700           6700           6700  6700         6700      6700
# male    6194           6194           6194  6194         6194      6194
#
#         tweet_location  user_timezone
# gender
# female            4278           4353
# male              4469           4144

# %%
df['gender'] = df['gender'].fillna('male')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12991 non-null  int64
#  1   _golden                12991 non-null  bool
#  2   _unit_state            12991 non-null  object
#  3   _trusted_judgments     12991 non-null  int64
#  4   gender                 12991 non-null  object
#  5   gender:confidence      12965 non-null  float64
#  6   profile_yn             12991 non-null  object
#  7   profile_yn:confidence  12991 non-null  float64
#  8   created                12991 non-null  object
#  9   fav_number             12991 non-null  int64
#  10  link_color             12991 non-null  object
#  11  name                   12991 non-null  object
#  12  retweet_count          12991 non-null  int64
#  13  sidebar_color          12991 non-null  object
# ...

# %%
df['gender:confidence'].values[0]
# Out:
# 1.0

# %%
df['gender:confidence'].mean()
# Out:
# 0.9111364751253374

# %%
avg=df['gender:confidence'].mean()
print(avg)
avg_round=round(avg,4)
print(avg_round)
# Out:
# 0.9111364751253374
# 0.9111

# %%
avg_round
# Out:
# 0.9111

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12991 non-null  int64
#  1   _golden                12991 non-null  bool
#  2   _unit_state            12991 non-null  object
#  3   _trusted_judgments     12991 non-null  int64
#  4   gender                 12991 non-null  object
#  5   gender:confidence      12965 non-null  float64
#  6   profile_yn             12991 non-null  object
#  7   profile_yn:confidence  12991 non-null  float64
#  8   created                12991 non-null  object
#  9   fav_number             12991 non-null  int64
#  10  link_color             12991 non-null  object
#  11  name                   12991 non-null  object
#  12  retweet_count          12991 non-null  int64
#  13  sidebar_color          12991 non-null  object
# ...

# %%
df.head(20)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments  gender  \
# 0   815719226    False   finalized                   3    male
# 1   815719227    False   finalized                   3    male
# 2   815719228    False   finalized                   3    male
# 3   815719229    False   finalized                   3    male
# 4   815719230    False   finalized                   3  female
# 5   815719231    False   finalized                   3  female
# 7   815719233    False   finalized                   3    male
# 8   815719234    False   finalized                   3  female
# 9   815719235    False   finalized                   3  female
# 12  815719238    False   finalized                   3  female
# 14  815719240    False   finalized                   3  female
# 15  815719241    False   finalized                   3  female
# 16  815719242    False   finalized                   3  female
# 17  815719243    False   finalized                   3    male
# ...

# %%
df["gender:confidence"].replace({"avg_round":avg_round}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12991 non-null  int64
#  1   _golden                12991 non-null  bool
#  2   _unit_state            12991 non-null  object
#  3   _trusted_judgments     12991 non-null  int64
#  4   gender                 12991 non-null  object
#  5   gender:confidence      12965 non-null  float64
#  6   profile_yn             12991 non-null  object
#  7   profile_yn:confidence  12991 non-null  float64
#  8   created                12991 non-null  object
#  9   fav_number             12991 non-null  int64
#  10  link_color             12991 non-null  object
#  11  name                   12991 non-null  object
#  12  retweet_count          12991 non-null  int64
#  13  sidebar_color          12991 non-null  object
# ...

# %%
df.head(20)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments  gender  \
# 0   815719226    False   finalized                   3    male
# 1   815719227    False   finalized                   3    male
# 2   815719228    False   finalized                   3    male
# 3   815719229    False   finalized                   3    male
# 4   815719230    False   finalized                   3  female
# 5   815719231    False   finalized                   3  female
# 7   815719233    False   finalized                   3    male
# 8   815719234    False   finalized                   3  female
# 9   815719235    False   finalized                   3  female
# 12  815719238    False   finalized                   3  female
# 14  815719240    False   finalized                   3  female
# 15  815719241    False   finalized                   3  female
# 16  815719242    False   finalized                   3  female
# 17  815719243    False   finalized                   3    male
# ...

# %%
df['tweet_location'].value_counts()
# Out:
# London                          98
# Los Angeles, CA                 51
# United States                   49
# UK                              45
# London, England                 36
#                                 ..
# 126                              1
# 22 FLÏöüOH                    1
# okotoks ab.                      1
# Death City or Angel's Domain     1
# Trap'House                       1
# Name: tweet_location, Length: 6100, dtype: int64

# %%
df['tweet_location'] = df['tweet_location'].fillna('London')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               12991 non-null  int64
#  1   _golden                12991 non-null  bool
#  2   _unit_state            12991 non-null  object
#  3   _trusted_judgments     12991 non-null  int64
#  4   gender                 12991 non-null  object
#  5   gender:confidence      12965 non-null  float64
#  6   profile_yn             12991 non-null  object
#  7   profile_yn:confidence  12991 non-null  float64
#  8   created                12991 non-null  object
#  9   fav_number             12991 non-null  int64
#  10  link_color             12991 non-null  object
#  11  name                   12991 non-null  object
#  12  retweet_count          12991 non-null  int64
#  13  sidebar_color          12991 non-null  object
# ...

# %%
df.drop(['_unit_id'],axis=1,inplace=True)

# %%
df.head(20)
# Out:
#     _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0     False   finalized                   3    male             1.0000
# 1     False   finalized                   3    male             1.0000
# 2     False   finalized                   3    male             0.6625
# 3     False   finalized                   3    male             1.0000
# 4     False   finalized                   3  female             1.0000
# 5     False   finalized                   3  female             1.0000
# 7     False   finalized                   3    male             1.0000
# 8     False   finalized                   3  female             1.0000
# 9     False   finalized                   3  female             1.0000
# 12    False   finalized                   3  female             0.6509
# 14    False   finalized                   3  female             0.6501
# 15    False   finalized                   3  female             1.0000
# ...

# %%
df['_trusted_judgments'].value_counts()
# Out:
# 3      12955
# 259        4
# 249        4
# 242        3
# 247        2
# 264        2
# 227        2
# 260        2
# 253        1
# 239        1
# 231        1
# 270        1
# 262        1
# 254        1
# 261        1
# 240        1
# 245        1
# 228        1
# 248        1
# 235        1
# 274        1
# 258        1
# 250        1
# 256        1
# 255        1
# Name: _trusted_judgments, dtype: int64

# %%
df['profile_yn'].value_counts()
# Out:
# yes    12894
# no        97
# Name: profile_yn, dtype: int64

# %%
df.dtypes
# Out:
# _golden                     bool
# _unit_state               object
# _trusted_judgments         int64
# gender                    object
# gender:confidence        float64
# profile_yn                object
# profile_yn:confidence    float64
# created                   object
# fav_number                 int64
# link_color                object
# name                      object
# retweet_count              int64
# sidebar_color             object
# text                      object
# tweet_count                int64
# tweet_id                 float64
# tweet_location            object
# user_timezone             object
# dtype: object

# %%
df.head(20)
# Out:
#     _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0     False   finalized                   3    male             1.0000
# 1     False   finalized                   3    male             1.0000
# 2     False   finalized                   3    male             0.6625
# 3     False   finalized                   3    male             1.0000
# 4     False   finalized                   3  female             1.0000
# 5     False   finalized                   3  female             1.0000
# 7     False   finalized                   3    male             1.0000
# 8     False   finalized                   3  female             1.0000
# 9     False   finalized                   3  female             1.0000
# 12    False   finalized                   3  female             0.6509
# 14    False   finalized                   3  female             0.6501
# 15    False   finalized                   3  female             1.0000
# ...

# %%
df['_golden'].value_counts()
# Out:
# False    12955
# True        36
# Name: _golden, dtype: int64

# %%
df.columns
# Out:
# Index(['_golden', '_unit_state', '_trusted_judgments', 'gender',
#        'gender:confidence', 'profile_yn', 'profile_yn:confidence', 'created',
#        'fav_number', 'link_color', 'name', 'retweet_count', 'sidebar_color',
#        'text', 'tweet_count', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# False    12955
# True        36
# Name: _golden, dtype: int64
# finalized    12955
# golden          36
# Name: _unit_state, dtype: int64
# 3      12955
# 259        4
# 249        4
# 242        3
# 247        2
# 264        2
# 227        2
# 260        2
# 253        1
# 239        1
# 231        1
# 270        1
# 262        1
# 254        1
# 261        1
# 240        1
# 245        1
# 228        1
# 248        1
# 235        1
# 274        1
# 258        1
# 250        1
# 256        1
# 255        1
# Name: _trusted_judgments, dtype: int64
# female    6700
# male      6291
# Name: gender, dtype: int64
# 1.0000    10020
# 0.0000       71
# 0.6691       18
# 0.6667       17
# 0.6678       16
#           ...
# 0.8472        1
# 0.3353        1
# 0.3398        1
# 0.6373        1
# 0.7023        1
# Name: gender:confidence, Length: 792, dtype: int64
# yes    12894
# no        97
# Name: profile_yn, dtype: int64
# 1.0000    12721
# 0.6557        6
# 0.6636        4
# ...

# %%
df.dtypes
# Out:
# _golden                     bool
# _unit_state               object
# _trusted_judgments         int64
# gender                    object
# gender:confidence        float64
# profile_yn                object
# profile_yn:confidence    float64
# created                   object
# fav_number                 int64
# link_color                object
# name                      object
# retweet_count              int64
# sidebar_color             object
# text                      object
# tweet_count                int64
# tweet_id                 float64
# tweet_location            object
# user_timezone             object
# dtype: object

# %%
df.drop(['created'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _golden                12991 non-null  bool
#  1   _unit_state            12991 non-null  object
#  2   _trusted_judgments     12991 non-null  int64
#  3   gender                 12991 non-null  object
#  4   gender:confidence      12965 non-null  float64
#  5   profile_yn             12991 non-null  object
#  6   profile_yn:confidence  12991 non-null  float64
#  7   fav_number             12991 non-null  int64
#  8   link_color             12991 non-null  object
#  9   name                   12991 non-null  object
#  10  retweet_count          12991 non-null  int64
#  11  sidebar_color          12991 non-null  object
#  12  text                   12991 non-null  object
#  13  tweet_count            12991 non-null  int64
# ...

# %%
df['name'].unique
# Out:
# <bound method Series.unique of 0               sheezy0
# 1           DavdBurnett
# 2        lwtprettylaugh
# 3           douggarland
# 4          WilfordGemma
#               ...
# 20045       capuletrosa
# 20046        BenNight41
# 20047     realuzzyfluxz
# 20048      argumatronic
# 20049       MeganFitz20
# Name: name, Length: 12991, dtype: object>

# %%
df.groupby(['name']).count()
# Out:
#                 _golden  _unit_state  _trusted_judgments  gender  \
# name
# 0154_GUTIERREZ        1            1                   1       1
# 01808gnlb             1            1                   1       1
# 01LBrown              2            2                   2       2
# 01paigee              1            1                   1       1
# 03Aisla               1            1                   1       1
# ...                 ...          ...                 ...     ...
# zooffyrolling         1            1                   1       1
# zowiekelilaa          1            1                   1       1
# zruxmusic             1            1                   1       1
# zuli786               1            1                   1       1
# zyxy_nana             1            1                   1       1
#
#                 gender:confidence  profile_yn  profile_yn:confidence  \
# name
# 0154_GUTIERREZ                  1           1                      1
# ...

# %%
df.drop(['text'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _golden                12991 non-null  bool
#  1   _unit_state            12991 non-null  object
#  2   _trusted_judgments     12991 non-null  int64
#  3   gender                 12991 non-null  object
#  4   gender:confidence      12965 non-null  float64
#  5   profile_yn             12991 non-null  object
#  6   profile_yn:confidence  12991 non-null  float64
#  7   fav_number             12991 non-null  int64
#  8   link_color             12991 non-null  object
#  9   name                   12991 non-null  object
#  10  retweet_count          12991 non-null  int64
#  11  sidebar_color          12991 non-null  object
#  12  tweet_count            12991 non-null  int64
#  13  tweet_id               12991 non-null  float64
# ...

# %%
df.head(20)
# Out:
#     _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0     False   finalized                   3    male             1.0000
# 1     False   finalized                   3    male             1.0000
# 2     False   finalized                   3    male             0.6625
# 3     False   finalized                   3    male             1.0000
# 4     False   finalized                   3  female             1.0000
# 5     False   finalized                   3  female             1.0000
# 7     False   finalized                   3    male             1.0000
# 8     False   finalized                   3  female             1.0000
# 9     False   finalized                   3  female             1.0000
# 12    False   finalized                   3  female             0.6509
# 14    False   finalized                   3  female             0.6501
# 15    False   finalized                   3  female             1.0000
# ...

# %%
df.groupby(['sidebar_color']).count()
# Out:
#                _golden  _unit_state  _trusted_judgments  gender  \
# sidebar_color
# 0                 2734         2734                2734    2734
# 00090A               1            1                   1       1
# 001B5E               1            1                   1       1
# 002D7A               1            1                   1       1
# 005A87               1            1                   1       1
# ...                ...          ...                 ...     ...
# FFDE00               1            1                   1       1
# FFF1E8               1            1                   1       1
# FFF8AD              55           55                  55      55
# FFFAFA               1            1                   1       1
# FFFFFF            2681         2681                2681    2681
#
#                gender:confidence  profile_yn  profile_yn:confidence  \
# sidebar_color
# 0                           2726        2734                   2734
# ...

# %%
df.groupby(['user_timezone']).count()
# Out:
#                      _golden  _unit_state  _trusted_judgments  gender  \
# user_timezone
# Abu Dhabi                 20           20                  20      20
# Adelaide                   4            4                   4       4
# Africa/Cairo               1            1                   1       1
# Africa/Lagos               1            1                   1       1
# Africa/Nairobi             1            1                   1       1
# ...                      ...          ...                 ...     ...
# Wellington                16           16                  16      16
# West Central Africa       23           23                  23      23
# Yakutsk                    4            4                   4       4
# Yerevan                    4            4                   4       4
# Zagreb                     6            6                   6       6
#
#                      gender:confidence  profile_yn  profile_yn:confidence  \
# user_timezone
# ...

# %%
df['user_timezone'].values[0][0]
# Out:
# 'C'

# %%
df['user_timezone'].values[0].split(' ')[0]
# Out:
# 'Chennai'

# %%
df_timezone=df[['user_timezone']]

# %%
df_timezone
# Out:
#                     user_timezone
# 0                         Chennai
# 1      Eastern Time (US & Canada)
# 2                        Belgrade
# 3      Pacific Time (US & Canada)
# 4                             NaN
# ...                           ...
# 20045                         NaN
# 20046                         NaN
# 20047                         NaN
# 20048                         NaN
# 20049                         NaN
#
# [12991 rows x 1 columns]

# %%
df_timezone['user_timezone'].value_counts()
# Out:
# Eastern Time (US & Canada)        1672
# Pacific Time (US & Canada)        1360
# Central Time (US & Canada)        1099
# London                             907
# Atlantic Time (Canada)             445
#                                   ...
# EDT                                  1
# America/Vancouver                    1
# America/Argentina/Buenos_Aires       1
# Africa/Lagos                         1
# America/Boise                        1
# Name: user_timezone, Length: 148, dtype: int64

# %%
df_timezone['user_timezone'].values[0].split(' ')[0]
# Out:
# 'Chennai'

# %%
df
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
df_mp1=df
df_mp2=df
df_mp3=df
df_mp4=df

# %%
df_mp1
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
current_title = df['user_timezone'].values[1]
list_of_title_words = current_title.split(' ')[0]
print(list_of_title_words)
# Out:
# Eastern

# %%
df
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
df['user_timezone'].value_counts()
# Out:
# Eastern Time (US & Canada)        1672
# Pacific Time (US & Canada)        1360
# Central Time (US & Canada)        1099
# London                             907
# Atlantic Time (Canada)             445
#                                   ...
# EDT                                  1
# America/Vancouver                    1
# America/Argentina/Buenos_Aires       1
# Africa/Lagos                         1
# America/Boise                        1
# Name: user_timezone, Length: 148, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _golden                12991 non-null  bool
#  1   _unit_state            12991 non-null  object
#  2   _trusted_judgments     12991 non-null  int64
#  3   gender                 12991 non-null  object
#  4   gender:confidence      12965 non-null  float64
#  5   profile_yn             12991 non-null  object
#  6   profile_yn:confidence  12991 non-null  float64
#  7   fav_number             12991 non-null  int64
#  8   link_color             12991 non-null  object
#  9   name                   12991 non-null  object
#  10  retweet_count          12991 non-null  int64
#  11  sidebar_color          12991 non-null  object
#  12  tweet_count            12991 non-null  int64
#  13  tweet_id               12991 non-null  float64
# ...

# %%
df['user_timezone'] = df['user_timezone'].fillna('Eastern Time (US & Canada)')

# %%
df
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
for i in range(df.shape[0]):
    current_title = df['user_timezone'].values[i]
    list_of_title_words = current_title.split(' ')[0]
    df['user_timezone'].values[i] = list_of_title_words

# %%
df
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
df['user_timezone'].value_counts()
# Out:
# Eastern                           6099
# Pacific                           1360
# Central                           1104
# London                             907
# Atlantic                           445
#                                   ...
# Minsk                                1
# America/Argentina/Buenos_Aires       1
# Europe/Sarajevo                      1
# Dhaka                                1
# America/Boise                        1
# Name: user_timezone, Length: 146, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _golden                12991 non-null  bool
#  1   _unit_state            12991 non-null  object
#  2   _trusted_judgments     12991 non-null  int64
#  3   gender                 12991 non-null  object
#  4   gender:confidence      12965 non-null  float64
#  5   profile_yn             12991 non-null  object
#  6   profile_yn:confidence  12991 non-null  float64
#  7   fav_number             12991 non-null  int64
#  8   link_color             12991 non-null  object
#  9   name                   12991 non-null  object
#  10  retweet_count          12991 non-null  int64
#  11  sidebar_color          12991 non-null  object
#  12  tweet_count            12991 non-null  int64
#  13  tweet_id               12991 non-null  float64
# ...

# %%
cat_col = set(df.columns) - set(df.describe().columns)

# %%
df.columns
# Out:
# Index(['_golden', '_unit_state', '_trusted_judgments', 'gender',
#        'gender:confidence', 'profile_yn', 'profile_yn:confidence',
#        'fav_number', 'link_color', 'name', 'retweet_count', 'sidebar_color',
#        'tweet_count', 'tweet_id', 'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
cat_col
# Out:
# {'_golden',
#  '_unit_state',
#  'gender',
#  'link_color',
#  'name',
#  'profile_yn',
#  'sidebar_color',
#  'tweet_location',
#  'user_timezone'}

# %%
df
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
df_mp1=df
df_mp2=df
df_mp3=df
df_mp4=df

# %%
df_mp1
# Out:
#        _golden _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0        False   finalized                   3    male             1.0000
# 1        False   finalized                   3    male             1.0000
# 2        False   finalized                   3    male             0.6625
# 3        False   finalized                   3    male             1.0000
# 4        False   finalized                   3  female             1.0000
# ...        ...         ...                 ...     ...                ...
# 20045     True      golden                 259  female             1.0000
# 20046     True      golden                 248    male             1.0000
# 20047     True      golden                 264    male             1.0000
# 20048     True      golden                 250  female             0.8489
# 20049     True      golden                 249  female             1.0000
#
#       profile_yn  profile_yn:confidence  fav_number link_color  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for each_col in cat_col:
    le = LabelEncoder()
    df[each_col] = le.fit_transform(df[each_col])

# %%
df
# Out:
#        _golden  _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0            0            0                   3       1             1.0000
# 1            0            0                   3       1             1.0000
# 2            0            0                   3       1             0.6625
# 3            0            0                   3       1             1.0000
# 4            0            0                   3       0             1.0000
# ...        ...          ...                 ...     ...                ...
# 20045        1            1                 259       0             1.0000
# 20046        1            1                 248       1             1.0000
# 20047        1            1                 264       1             1.0000
# 20048        1            1                 250       0             0.8489
# 20049        1            1                 249       0             1.0000
#
# ...

# %%
df_mp1=df
df_mp2=df
df_mp3=df
df_mp4=df

# %%
df_mp1
# Out:
#        _golden  _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0            0            0                   3       1             1.0000
# 1            0            0                   3       1             1.0000
# 2            0            0                   3       1             0.6625
# 3            0            0                   3       1             1.0000
# 4            0            0                   3       0             1.0000
# ...        ...          ...                 ...     ...                ...
# 20045        1            1                 259       0             1.0000
# 20046        1            1                 248       1             1.0000
# 20047        1            1                 264       1             1.0000
# 20048        1            1                 250       0             0.8489
# 20049        1            1                 249       0             1.0000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _golden                12991 non-null  int64
#  1   _unit_state            12991 non-null  int32
#  2   _trusted_judgments     12991 non-null  int64
#  3   gender                 12991 non-null  int32
#  4   gender:confidence      12965 non-null  float64
#  5   profile_yn             12991 non-null  int32
#  6   profile_yn:confidence  12991 non-null  float64
#  7   fav_number             12991 non-null  int64
#  8   link_color             12991 non-null  int32
#  9   name                   12991 non-null  int32
#  10  retweet_count          12991 non-null  int64
#  11  sidebar_color          12991 non-null  int32
#  12  tweet_count            12991 non-null  int64
#  13  tweet_id               12991 non-null  float64
# ...

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp=MLPClassifier(hidden_layer_sizes=(10,),activation='relu',solver='adam',verbose=True)

# %%
import numpy as np
predict = "gender"
X = np.array(df.drop("gender",axis=1))
y = np.array(df[predict])

# %%
X.shape
# Out:
# (12991, 15)

# %%
y.shape[0]
# Out:
# 12991

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7)

# %%
mlp.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-119-12e97e9b7099> in <module>
# ----> 1 mlp.fit(X_train,y_train)
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#     671         self : returns a trained MLP model.
#     672         """
# --> 673         return self._fit(X, y, incremental=False)
#     674
#     675     @property
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     362                       (not self.warm_start and not incremental))
#     363
# --> 364         X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     365
#     366         n_samples, n_features = X.shape
#
# ...

# %%
df
# Out:
#        _golden  _unit_state  _trusted_judgments  gender  gender:confidence  \
# 0            0            0                   3       1             1.0000
# 1            0            0                   3       1             1.0000
# 2            0            0                   3       1             0.6625
# 3            0            0                   3       1             1.0000
# 4            0            0                   3       0             1.0000
# ...        ...          ...                 ...     ...                ...
# 20045        1            1                 259       0             1.0000
# 20046        1            1                 248       1             1.0000
# 20047        1            1                 264       1             1.0000
# 20048        1            1                 250       0             0.8489
# 20049        1            1                 249       0             1.0000
#
# ...

# %%
df['gender:confidence'] = df['gender:confidence'].fillna(avg_round)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12991 entries, 0 to 20049
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _golden                12991 non-null  int64
#  1   _unit_state            12991 non-null  int32
#  2   _trusted_judgments     12991 non-null  int64
#  3   gender                 12991 non-null  int32
#  4   gender:confidence      12991 non-null  float64
#  5   profile_yn             12991 non-null  int32
#  6   profile_yn:confidence  12991 non-null  float64
#  7   fav_number             12991 non-null  int64
#  8   link_color             12991 non-null  int32
#  9   name                   12991 non-null  int32
#  10  retweet_count          12991 non-null  int64
#  11  sidebar_color          12991 non-null  int32
#  12  tweet_count            12991 non-null  int64
#  13  tweet_id               12991 non-null  float64
# ...

# %%
import numpy as np
predict = "gender"
X = np.array(df.drop("gender",axis=1))
y = np.array(df[predict])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7)

# %%
mlp.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 17.45301221
# Iteration 2, loss = 17.42526465
# Iteration 3, loss = 17.94453399
# Iteration 4, loss = 17.82165316
# Iteration 5, loss = 17.88507521
# Iteration 6, loss = 18.09119735
# Iteration 7, loss = 18.01588331
# Iteration 8, loss = 17.96435264
# Iteration 9, loss = 17.93264145
# Iteration 10, loss = 17.90093027
# Iteration 11, loss = 18.10705251
# Iteration 12, loss = 17.71859124
# Iteration 13, loss = 18.18236636
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(10,), verbose=True)

# %%
mlp=MLPClassifier(hidden_layer_sizes=(30,4),activation='relu',solver='adam',verbose=True)

# %%
mlp.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 18.59065180
# Iteration 2, loss = 14.10611454
# Iteration 3, loss = 0.70110173
# Iteration 4, loss = 0.70066074
# Iteration 5, loss = 0.70014609
# Iteration 6, loss = 0.69959570
# Iteration 7, loss = 0.69903982
# Iteration 8, loss = 0.69847242
# Iteration 9, loss = 0.69792665
# Iteration 10, loss = 0.69739152
# Iteration 11, loss = 0.69687602
# Iteration 12, loss = 0.69641006
# Iteration 13, loss = 0.69595441
# Iteration 14, loss = 0.69555203
# Iteration 15, loss = 0.69517467
# Iteration 16, loss = 0.69484093
# Iteration 17, loss = 0.69454050
# Iteration 18, loss = 1.09898350
# Iteration 19, loss = 0.69395294
# Iteration 20, loss = 0.69375942
# Iteration 21, loss = 0.69357960
# Iteration 22, loss = 0.69342878
# Iteration 23, loss = 0.69329768
# Iteration 24, loss = 0.69318710
# Iteration 25, loss = 0.69310248
# Iteration 26, loss = 0.69301343
# Iteration 27, loss = 0.69294796
# Iteration 28, loss = 0.69288759
# Iteration 29, loss = 0.69283936
# ...

# %%
mlp.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
Y_pred_nn=mlp.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, Y_pred_nn)
# Out:
# 0.5156490507952797

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalized_data=MinMaxScaler().fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(normalized_data,y,train_size=0.7)

# %%
mlp.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 0.71806736
# Iteration 2, loss = 0.69587838
# Iteration 3, loss = 0.69262122
# Iteration 4, loss = 0.69004556
# Iteration 5, loss = 0.68772119
# Iteration 6, loss = 0.68573763
# Iteration 7, loss = 0.68335554
# Iteration 8, loss = 0.68141056
# Iteration 9, loss = 0.67921342
# Iteration 10, loss = 0.67682216
# Iteration 11, loss = 0.67449230
# Iteration 12, loss = 0.67378451
# Iteration 13, loss = 0.67245143
# Iteration 14, loss = 0.67257302
# Iteration 15, loss = 0.67048144
# Iteration 16, loss = 0.66945431
# Iteration 17, loss = 0.66846840
# Iteration 18, loss = 0.66859978
# Iteration 19, loss = 0.66707025
# Iteration 20, loss = 0.66660789
# Iteration 21, loss = 0.66639617
# Iteration 22, loss = 0.66588878
# Iteration 23, loss = 0.66626377
# Iteration 24, loss = 0.66541392
# Iteration 25, loss = 0.66508877
# Iteration 26, loss = 0.66471121
# Iteration 27, loss = 0.66478504
# Iteration 28, loss = 0.66421756
# Iteration 29, loss = 0.66351059
# ...

# %%
Y_pred_nn=mlp.predict(X_test)

# %%
accuracy_score(y_test, Y_pred_nn)
# Out:
# 0.5746536685479733

# %%
mlp.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from keras.optimizers import Adam

# %%
from tensorflow.keras.layers import Input, Dense, Activation

# %%
from tensorflow.keras import Sequential

# %%
model=Sequential()
model.add(Input(shape=(15,)),)
model.add(Dense(35,activation='relu'),)
model.add(Dense(40,activation='relu'),)
model.add(Dense(30,activation='relu'),)
model.add(Dense(2,activation='softmax'),)

# %%
opt=Adam(learning_rate=0.000009)

# %%
model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
X_train,X_test,y_train,y_test = train_test_split(normalized_data,y,train_size=0.7)

# %%
model.fit(X_train,y_train,epochs=150,)
# Out:
# Epoch 1/150
# 285/285 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5046
# Epoch 2/150
# 285/285 [==============================] - 0s 944us/step - loss: 0.6931 - accuracy: 0.5053
# Epoch 3/150
# 285/285 [==============================] - 0s 997us/step - loss: 0.6931 - accuracy: 0.4994
# Epoch 4/150
# 285/285 [==============================] - 0s 943us/step - loss: 0.6931 - accuracy: 0.5017
# Epoch 5/150
# 285/285 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.4997
# Epoch 6/150
# 285/285 [==============================] - 0s 913us/step - loss: 0.6931 - accuracy: 0.4994
# Epoch 7/150
# 285/285 [==============================] - 0s 862us/step - loss: 0.6931 - accuracy: 0.5064
# Epoch 8/150
# 285/285 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.5010
# Epoch 9/150
# 285/285 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.5007
# Epoch 10/150
# ...
